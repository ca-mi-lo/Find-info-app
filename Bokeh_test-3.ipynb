# %%
from pathlib import Path
from find_info_app import graphs

# %%
path = "./papers/datasets/one_shot_classif.csv"
my_instance = graphs.DataProcessor.read_file(path)
my_instance.DataProcessor.df_pivoted()
# Out:
# Default file loaded: "./papers/datasets/one_shot_classif.csv"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 path = "./papers/datasets/one_shot_classif.csv"
#       2 my_instance = graphs.DataProcessor.read_file(path)
# ----> 3 my_instance.DataProcessor.df_pivoted()
#
# AttributeError: 'NoneType' object has no attribute 'DataProcessor'

# %%
import pandas as pd
temp = pd.read_csv(path)

# %%
temp
# Out:
#                                           page_content  \
# 0    Journal of Apicultural Research , 2015\n[http:...
# 1    ( Received 12 March 2011; accepted 18 December...
# 2    Distribucio ´n de abejas sin aguijo ´ns y riqu...
# 3    Este es el primer inventario completo de abeja...
# 4    .1, P &lt; 0.001) y a ´rboles frutales (X ² = ...
# ..                                                 ...
# 100  **Acknowledgements**\n\nNydia and Luis Alberto...
# 101  **References**\n\nBiesmeijer, J.C., M.G.L. van...
# 102  Lindauer, M., 1952. Ein Beitrag zur Frage der ...
# 103  .E. and R.E. Page, Jr., 1989. Genetic determin...
# 104  Received 11 August 1997;\nrevised 13 February ...
#
#                                                 source   format  \
# 0    papers/test_samples/Ruano-Iraheta et al., 2015...  PDF 1.6
# 1    papers/test_samples/Ruano-Iraheta et al., 2015...  PDF 1.6
# 2    papers/test_samples/Ruano-Iraheta et al., 2015...  PDF 1.6
# ...
